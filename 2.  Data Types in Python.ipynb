# %%
# Data Types

# %%
# 1. Basic Types

# %%
# i. Integer

# %%
print(1e308)
print(1e309)
# Out:
# 1e+308
# inf

# %%
# ii. Float

# %%
print(1.7e308)
print(1.7e309)
# Out:
# 1.7e+308
# inf

# %%
# iii. Boolean

# %%
print(True)
print(False)
# Out:
# True
# False

# %%
# iv. Complex

# %%
print(10+7j)
# Out:
# (10+7j)

# %%
# v. String

# %%
print('Karachi')
print("Karachi")
print("""Karachi""")
# Out:
# Karachi
# Karachi
# Karachi

# %%
# 2. Container Types

# %%
# i. List

# %%
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# ii. Tuple

# %%
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
# iii. Sets

# %%
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
# iv. Dictionary
print({"Name":"Abdul Subhan","Age":"17","gender":"Male"})
# Out:
# {'Name': 'Abdul Subhan', 'Age': '17', 'gender': 'Male'}
